# %% [markdown]
# <a href="https://colab.research.google.com/github/arooshasolomon/ds1002-npj4qa/blob/main/homework/week-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework - Week 6
#
# Complete the following blocks as specified in the directions. Run each cell to return the desired output. Save your notebook back to your GitHub repository and submit the GitHub URL for your notebook for review.

# %% [markdown]
# # Pandas
#
# ## 1. Fetch and Load Data
# In class we created a DataFrame using the `read_csv` method. Go to https://catalog.data.gov/dataset/electric-vehicle-population-data and download the CSV format of the "Electric Vehicle Population Data" dataset. Then upload it to Google Colab.
#
# Load that data into a Pandas DataFrame and display the first 20 rows. Show your work.

# %%
# Set up pandas and populate the dataframe above using the raw data. Then continue to work with the dataframe in the questions below.

import pandas as pd



df = pd.read_csv('/Data.csv')
df
# Out:
#        VIN (1-10)     County           City State  Postal Code  Model Year  \
# 0      KM8K33AGXL       King        Seattle    WA        98103      2020.0
# 1      1C4RJYB61N       King        Bothell    WA        98011      2022.0
# 2      1C4RJYD61P     Yakima         Yakima    WA        98908      2023.0
# 3      5YJ3E1EA7J       King       Kirkland    WA        98034      2018.0
# 4      WBY7Z8C5XJ   Thurston        Olympia    WA        98501      2018.0
# ...           ...        ...            ...   ...          ...         ...
# 78713  7SAYGAEE7N  Snohomish      Snohomish    WA        98296      2022.0
# 78714  1FTBW9CK7P       King    Woodinville    WA        98072      2023.0
# 78715  3FMTK2SU8P   Thurston        Olympia    WA        98501      2023.0
# 78716  5YJ3E1EB4N       King      Sammamish    WA        98075      2022.0
# 78717  7SAYGDEE7N       King  Mercer Island    WA            9         NaN
#
#           Make           Model                   Electric Vehicle Type  \
# 0      HYUNDAI            KONA          Battery Electric Vehicle (BEV)
# 1         JEEP  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 2         JEEP  GRAND CHEROKEE  Plug-in Hybrid Electric Vehicle (PHEV)
# 3        TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 4          BMW              I3  Plug-in Hybrid Electric Vehicle (PHEV)
# ...        ...             ...                                     ...
# 78713    TESLA         MODEL Y          Battery Electric Vehicle (BEV)
# 78714     FORD         TRANSIT          Battery Electric Vehicle (BEV)
# 78715     FORD  MUSTANG MACH-E          Battery Electric Vehicle (BEV)
# 78716    TESLA         MODEL 3          Battery Electric Vehicle (BEV)
# 78717      NaN             NaN                                     NaN
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0                Clean Alternative Fuel Vehicle Eligible           258.0
# 1                  Not eligible due to low battery range            25.0
# 2                  Not eligible due to low battery range            25.0
# 3                Clean Alternative Fuel Vehicle Eligible           215.0
# 4                Clean Alternative Fuel Vehicle Eligible            97.0
# ...                                                  ...             ...
# 78713  Eligibility unknown as battery range has not b...             0.0
# 78714  Eligibility unknown as battery range has not b...             0.0
# 78715  Eligibility unknown as battery range has not b...             0.0
# 78716  Eligibility unknown as battery range has not b...             0.0
# 78717                                                NaN             NaN
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 0            0.0                  43.0     249675142.0
# 1            0.0                   1.0     233928502.0
# 2            0.0                  14.0     229675939.0
# 3            0.0                  45.0     104714466.0
# 4            0.0                  22.0     185498386.0
# ...          ...                   ...             ...
# 78713        0.0                  44.0     185726194.0
# 78714        0.0                  45.0     234998459.0
# 78715        0.0                  22.0     253792941.0
# 78716        0.0                  41.0     207710821.0
# 78717        NaN                   NaN             NaN
#
#                       Vehicle Location  \
# 0         POINT (-122.34301 47.659185)
# 1         POINT (-122.20578 47.762405)
# 2      POINT (-120.6027202 46.5965625)
# 3         POINT (-122.209285 47.71124)
# 4         POINT (-122.89692 47.043535)
# ...                                ...
# 78713    POINT (-122.15134 47.8851158)
# 78714     POINT (-122.151665 47.75855)
# 78715     POINT (-122.89692 47.043535)
# 78716      POINT (-122.03309 47.58153)
# 78717                              NaN
#
#                                     Electric Utility  2020 Census Tract
# 0       CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 1      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 2                                         PACIFICORP       5.307700e+10
# 3      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 4                             PUGET SOUND ENERGY INC       5.306701e+10
# ...                                              ...                ...
# 78713                         PUGET SOUND ENERGY INC       5.306104e+10
# 78714  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 78715                         PUGET SOUND ENERGY INC       5.306701e+10
# 78716  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 78717                                            NaN                NaN
#
# [78718 rows x 17 columns]

# %%
# Format a command that how many rows and columns are in this dataset.

df.shape
# Out:
# (78718, 17)

# %%
# Format a command that displays every other row of records 1000 through 1999, and the columns "City", "State", "Model Year", and "Make".

df.loc[1000:1999, ['City', 'State', 'Model Year', 'Make'] ]
# Out:
#            City State  Model Year     Make
# 1000     Auburn    WA      2022.0    TESLA
# 1001       Kent    WA      2018.0    TESLA
# 1002  Vancouver    WA      2021.0     JEEP
# 1003  Newcastle    WA      2022.0    TESLA
# 1004    Edmonds    WA      2022.0    TESLA
# ...         ...   ...         ...      ...
# 1995       Kent    WA      2023.0  HYUNDAI
# 1996    Seattle    WA      2020.0    VOLVO
# 1997  Vancouver    WA      2017.0   TOYOTA
# 1998    Olympia    WA      2022.0      KIA
# 1999     Seatac    WA      2022.0    TESLA
#
# [1000 rows x 4 columns]

# %% [markdown]
# # 2. Cleaning/Imputing Data
#
# In class we reviewed methods for removing duplicate rows and handling empty cell values. Download [this data set](https://github.com/nmagee/ds1002/blob/main/data/very-messy-data.csv) and upload into Google Colab.
#
# Create another Pandas DataFrame from that data and perform the following steps.

# %%
# Set up pandas and populate the dataframe above using the raw data. Then continue to work with the dataframe in the questions below.

df_2= pd.read_csv('/very-messy-data.csv')
df_2
# Out:
#        id  sepal_length  sepal_width  petal_length  petal_width    species
# 0       1           3.5          2.9           1.4          0.5  virginica
# 1       2           3.6          3.2           3.0          0.5     setosa
# 2       3           3.8          NaN           2.2          1.5     setosa
# 3       4           5.8          2.7           2.6          1.2  virginica
# 4       5           4.9          3.6           3.0          1.2  virginica
# ...   ...           ...          ...           ...          ...        ...
# 1311  412           NaN          3.6           2.9          0.5  virginica
# 1312  413           5.8          2.7           2.0          0.1  virginica
# 1313  414           3.3          3.7           1.3          2.8     setosa
# 1314  415           3.1          NaN           1.1          NaN  virginica
# 1315  416           4.3          2.5           1.3          1.0     setosa
#
# [1316 rows x 6 columns]

# %%
# Write a snippet of code that will display the number of duplicate rows exist in the DF.

dupes= df_2.duplicated()
print(dupes)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1311     True
# 1312     True
# 1313     True
# 1314     True
# 1315     True
# Length: 1316, dtype: bool

# %%
# Next, remove all duplicate rows using Python.

dupes2 = dupes.drop_duplicates()
print (dupes2)
# Out:
# 0       False
# 1000     True
# dtype: bool

# %%
# For the FOUR columns involving sepal and petal length and width, update all NaN
# values with the column mean such that NO empty cells remain. This method
# is called "imputation" because it fills in cells in a statistically less-impactful
# way than if they were blank.


new_values = df_2.loc[:, ['petal_width','petal_length', 'sepal_width', 'sepal_length']]
new_values




# Show how you would update those four columns in code
df_filled = new_values.fillna(new_values.mean())
df_filled
# Out:
#       petal_width  petal_length  sepal_width  sepal_length
# 0        0.500000           1.4     2.900000      3.500000
# 1        0.500000           3.0     3.200000      3.600000
# 2        1.500000           2.2     2.992747      3.800000
# 3        1.200000           2.6     2.700000      5.800000
# 4        1.200000           3.0     3.600000      4.900000
# ...           ...           ...          ...           ...
# 1311     0.500000           2.9     3.600000      4.529662
# 1312     0.100000           2.0     2.700000      5.800000
# 1313     2.800000           1.3     3.700000      3.300000
# 1314     1.558043           1.1     2.992747      3.100000
# 1315     1.000000           1.3     2.500000      4.300000
#
# [1316 rows x 4 columns]

# %% [markdown]
# # 3. Save to a New CSV
#
# Preserve your updated DF to a CSV file by using the method built into Pandas.
# Name the output file `very-clean-data.csv` and save it to GitHub in the same directory where you will save this homework. We will review both your Colab notebook and the cleaned data file.

# %%
df_filled.to_csv('/very-clean-data.csv')

pd.read_csv('/very-clean-data.csv')
# Out:
#       Unnamed: 0  petal_width  petal_length  sepal_width  sepal_length
# 0              0     0.500000           1.4     2.900000      3.500000
# 1              1     0.500000           3.0     3.200000      3.600000
# 2              2     1.500000           2.2     2.992747      3.800000
# 3              3     1.200000           2.6     2.700000      5.800000
# 4              4     1.200000           3.0     3.600000      4.900000
# ...          ...          ...           ...          ...           ...
# 1311        1311     0.500000           2.9     3.600000      4.529662
# 1312        1312     0.100000           2.0     2.700000      5.800000
# 1313        1313     2.800000           1.3     3.700000      3.300000
# 1314        1314     1.558043           1.1     2.992747      3.100000
# 1315        1315     1.000000           1.3     2.500000      4.300000
#
# [1316 rows x 5 columns]
