# %% [markdown]
# <a href="https://colab.research.google.com/github/arooshasolomon/ds1002-npj4qa/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd







# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
plt.pie(slices,labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7faeb858b670>,
#   <matplotlib.patches.Wedge at 0x7faeb858b580>,
#   <matplotlib.patches.Wedge at 0x7faeb85bc280>,
#   <matplotlib.patches.Wedge at 0x7faeb85bc910>,
#   <matplotlib.patches.Wedge at 0x7faeb85bcfa0>],
#  [Text(0.9349011005821531, 0.5796205069959818, 'US'),
#   Text(-0.21125715497921718, 1.079523234798625, 'UK'),
#   Text(-0.9728300181275684, 0.5134216160524556, 'MX'),
#   Text(-0.6116935558191647, -0.9142379306117783, 'CA'),
#   Text(0.9828146941303805, -0.49403975245055637, 'JP')],
#  [Text(0.5099460548629926, 0.31615664017962636, '17.7%'),
#   Text(-0.11523117544320936, 0.5888308553447045, '20.8%'),
#   Text(-0.53063455534231, 0.2800481542104303, '7.6%'),
#   Text(-0.3336510304468171, -0.4986752348791517, '39.1%'),
#   Text(0.5360807422529348, -0.26947622860939435, '14.8%')])

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n, bins=30, edgecolor='black')
# Out:
# (array([  1.,   1.,   1.,   0.,   4.,   4.,   9.,  20.,  25.,  60.,  95.,
#         104., 186., 217., 267., 283., 338., 316., 276., 227., 184., 154.,
#          91.,  61.,  33.,  25.,   7.,   7.,   2.,   2.]),
#  array([425.58045079, 425.84515416, 426.10985752, 426.37456088,
#         426.63926425, 426.90396761, 427.16867098, 427.43337434,
#         427.6980777 , 427.96278107, 428.22748443, 428.49218779,
#         428.75689116, 429.02159452, 429.28629789, 429.55100125,
#         429.81570461, 430.08040798, 430.34511134, 430.6098147 ,
#         430.87451807, 431.13922143, 431.4039248 , 431.66862816,
#         431.93333152, 432.19803489, 432.46273825, 432.72744161,
#         432.99214498, 433.25684834, 433.52155171]),
#  <BarContainer object of 30 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
plt.scatter(x, y, label='Data Points')
m, b = np.polyfit(x, y, 1)
plt.plot(x, m * x + b, color='red', label='Trendline')
